# %% [markdown]
# Problem statement: To build a CNN based model which can accurately detect melanoma. Melanoma is a type of cancer that can be deadly if not detected early. It accounts for 75% of skin cancer deaths. A solution which can evaluate images and alert the dermatologists about the presence of melanoma has the potential to reduce a lot of manual effort needed in diagnosis.

# %% [markdown]
# ### Importing Skin Cancer Data
# #### To do: Take necessary actions to read the data

# %% [markdown]
# ### Importing all the important libraries

# %%
import pathlib
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
import PIL
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %%
## If you are using the data by mounting the google drive, use the following :
## from google.colab import drive
## drive.mount('/content/gdrive')

##Ref:https://towardsdatascience.com/downloading-datasets-into-google-drive-via-google-colab-bcb1b30b0166

# %% [markdown]
# This assignment uses a dataset of about 2357 images of skin cancer types. The dataset contains 9 sub-directories in each train and test subdirectories. The 9 sub-directories contains the images of 9 skin cancer types respectively.

# %%
# Defining the path for train and test images
## Todo: Update the paths of the train and test dataset
data_dir_train = pathlib.Path("/content/drive/MyDrive/CNN/CNN_assignment.zip (Unzipped Files)/Skin cancer ISIC The International Skin Imaging Collaboration/Train")
data_dir_test = pathlib.Path('/content/drive/MyDrive/CNN/CNN_assignment.zip (Unzipped Files)/Skin cancer ISIC The International Skin Imaging Collaboration/Test')

# %%
image_count_train = len(list(data_dir_train.glob('*/*.jpg')))
print(image_count_train)
image_count_test = len(list(data_dir_test.glob('*/*.jpg')))
print(image_count_test)
# Out:
# 2239
# 118

# %% [markdown]
# ### Load using keras.preprocessing
#
# Let's load these images off disk using the helpful image_dataset_from_directory utility.

# %% [markdown]
# ### Create a dataset
#
# Define some parameters for the loader:

# %%
batch_size = 32
img_height = 180
img_width = 180

# %% [markdown]
# Use 80% of the images for training, and 20% for validation.

# %%
## Write your train dataset here
## Note use seed=123 while creating your dataset using tf.keras.preprocessing.image_dataset_from_directory
## Note, make sure your resize your images to the size img_height*img_width, while writting the dataset
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir_train,
    seed=123,
    validation_split= 0.2,
    subset= 'training',
    image_size=(img_height,img_width),
    batch_size = batch_size
)
# Out:
# Found 2239 files belonging to 9 classes.
# Using 1792 files for training.

# %%
## Write your validation dataset here
## Note use seed=123 while creating your dataset using tf.keras.preprocessing.image_dataset_from_directory
## Note, make sure your resize your images to the size img_height*img_width, while writting the dataset
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir_train,
    seed=123,
    validation_split= 0.2,
    subset= 'validation',
    image_size=(img_height,img_width),
    batch_size = batch_size
)
# Out:
# Found 2239 files belonging to 9 classes.
# Using 447 files for validation.

# %%
# List out all the classes of skin cancer and store them in a list. 
# You can find the class names in the class_names attribute on these datasets. 
# These correspond to the directory names in alphabetical order.
class_names = train_ds.class_names
print(class_names)
# Out:
# ['actinic keratosis', 'basal cell carcinoma', 'dermatofibroma', 'melanoma', 'nevus', 'pigmented benign keratosis', 'seborrheic keratosis', 'squamous cell carcinoma', 'vascular lesion']

# %% [markdown]
# ### Visualize the data
# #### Todo, create a code to visualize one instance of all the nine classes present in the dataset

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,10))
for i in range(9): 
  plt.subplot(3, 3, i + 1)
  image = plt.imread(str(list(data_dir_train.glob(class_names[i]+'/*.jpg'))[1]))
  plt.title(class_names[i])
  plt.imshow(image)

### your code goes here, you can use training or validation data to visualize

# %% [markdown]
# The `image_batch` is a tensor of the shape `(32, 180, 180, 3)`. This is a batch of 32 images of shape `180x180x3` (the last dimension refers to color channels RGB). The `label_batch` is a tensor of the shape `(32,)`, these are corresponding labels to the 32 images.

# %% [markdown]
# `Dataset.cache()` keeps the images in memory after they're loaded off disk during the first epoch.
#
# `Dataset.prefetch()` overlaps data preprocessing and model execution while training.

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# ### Create the model
# #### Todo: Create a CNN model, which can accurately detect 9 classes present in the dataset. Use ```layers.experimental.preprocessing.Rescaling``` to normalize pixel values between (0,1). The RGB channel values are in the `[0, 255]` range. This is not ideal for a neural network. Here, it is good to standardize values to be in the `[0, 1]`

# %%
### Your code goes here
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D
num_classes = 9
model = Sequential([
                    layers.experimental.preprocessing.Rescaling(1./255, input_shape=(img_height, img_width,3))
])
model.add(Conv2D(filters = 32, kernel_size = (5,5),padding = 'Same', 
                 activation ='relu', input_shape = (180, 180, 32)))
model.add(Conv2D(filters = 32, kernel_size = (5,5),padding = 'Same', 
                 activation ='relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Conv2D(filters = 32, kernel_size = (5,5),padding = 'Same', 
                 activation ='relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Conv2D(filters = 64, kernel_size = (5,5),padding = 'Same', 
                 activation ='relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Conv2D(filters = 64, kernel_size = (5,5),padding = 'Same', 
                 activation ='relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Dropout(0.25))


model.add(Flatten())
model.add(Dense(num_classes, activation = "softmax"))

# %% [markdown]
# ### Compile the model
# Choose an appropirate optimiser and loss function for model training

# %%
### Todo, choose an appropirate optimiser and loss function
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
# View the summary of all layers
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_1 (Rescaling)     (None, 180, 180, 3)       0
#
#  conv2d_2 (Conv2D)           (None, 180, 180, 32)      2432
#
#  conv2d_3 (Conv2D)           (None, 180, 180, 32)      25632
#
#  max_pooling2d_1 (MaxPooling  (None, 90, 90, 32)       0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 90, 90, 32)        25632
#
#  max_pooling2d_2 (MaxPooling  (None, 45, 45, 32)       0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 45, 45, 64)        51264
#
#  max_pooling2d_3 (MaxPooling  (None, 22, 22, 64)       0
#  2D)
#
#  conv2d_6 (Conv2D)           (None, 22, 22, 64)        102464
#
#  max_pooling2d_4 (MaxPooling  (None, 11, 11, 64)       0
#  2D)
#
#  dropout_1 (Dropout)         (None, 11, 11, 64)        0
#
#  flatten_1 (Flatten)         (None, 7744)              0
#
#  dense_1 (Dense)             (None, 9)                 69705
#
# =================================================================
# Total params: 277,129
# Trainable params: 277,129
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Train the model

# %%
epochs = 20
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/20
# 56/56 [==============================] - 20s 156ms/step - loss: 2.0535 - accuracy: 0.2042 - val_loss: 2.0276 - val_accuracy: 0.2058
# Epoch 2/20
# 56/56 [==============================] - 4s 78ms/step - loss: 2.0318 - accuracy: 0.1970 - val_loss: 2.0229 - val_accuracy: 0.2058
# Epoch 3/20
# 56/56 [==============================] - 4s 77ms/step - loss: 2.0180 - accuracy: 0.2054 - val_loss: 1.9673 - val_accuracy: 0.2528
# Epoch 4/20
# 56/56 [==============================] - 4s 77ms/step - loss: 1.9626 - accuracy: 0.2439 - val_loss: 1.9489 - val_accuracy: 0.2528
# Epoch 5/20
# 56/56 [==============================] - 4s 77ms/step - loss: 1.9723 - accuracy: 0.2427 - val_loss: 1.9792 - val_accuracy: 0.2371
# Epoch 6/20
# 56/56 [==============================] - 5s 81ms/step - loss: 1.9739 - accuracy: 0.2327 - val_loss: 1.9728 - val_accuracy: 0.2394
# Epoch 7/20
# 56/56 [==============================] - 4s 77ms/step - loss: 2.0265 - accuracy: 0.2338 - val_loss: 1.9560 - val_accuracy: 0.2617
# Epoch 8/20
# 56/56 [==============================] - 4s 76ms/step - loss: 1.9534 - accuracy: 0.2455 - val_loss: 1.9373 - val_accuracy: 0.3177
# Epoch 9/20
# 56/56 [==============================] - 4s 76ms/step - loss: 1.9591 - accuracy: 0.2455 - val_loss: 1.9753 - val_accuracy: 0.2371
# Epoch 10/20
# 56/56 [==============================] - 4s 76ms/step - loss: 1.9655 - accuracy: 0.2416 - val_loss: 1.9482 - val_accuracy: 0.2550
# Epoch 11/20
# 56/56 [==============================] - 4s 76ms/step - loss: 1.9654 - accuracy: 0.2221 - val_loss: 1.9624 - val_accuracy: 0.2528
# Epoch 12/20
# 56/56 [==============================] - 4s 76ms/step - loss: 1.9487 - accuracy: 0.2533 - val_loss: 2.0255 - val_accuracy: 0.2573
# Epoch 13/20
# 56/56 [==============================] - 4s 77ms/step - loss: 1.9828 - accuracy: 0.2416 - val_loss: 1.9779 - val_accuracy: 0.2394
# Epoch 14/20
# 56/56 [==============================] - 4s 77ms/step - loss: 1.9473 - accuracy: 0.2651 - val_loss: 1.9482 - val_accuracy: 0.2595
# Epoch 15/20
# 56/56 [==============================] - 4s 77ms/step - loss: 2.0377 - accuracy: 0.2383 - val_loss: 1.9556 - val_accuracy: 0.3356
# Epoch 16/20
# 56/56 [==============================] - 4s 77ms/step - loss: 1.9982 - accuracy: 0.2221 - val_loss: 1.9856 - val_accuracy: 0.2394
# Epoch 17/20
# 56/56 [==============================] - 4s 77ms/step - loss: 1.9714 - accuracy: 0.2416 - val_loss: 1.9929 - val_accuracy: 0.2550
# Epoch 18/20
# 56/56 [==============================] - 4s 77ms/step - loss: 1.9688 - accuracy: 0.2372 - val_loss: 1.9955 - val_accuracy: 0.2394
# Epoch 19/20
# 56/56 [==============================] - 4s 78ms/step - loss: 1.9842 - accuracy: 0.2416 - val_loss: 2.0095 - val_accuracy: 0.2550
# Epoch 20/20
# 56/56 [==============================] - 4s 77ms/step - loss: 1.9368 - accuracy: 0.2472 - val_loss: 2.0282 - val_accuracy: 0.2573

# %% [markdown]
# ### Visualizing training results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# #### Todo: Write your findings after the model fit, see if there is an evidence of model overfit or underfit
#
# ### model1
# #### `The model is overfitting because we can also see difference in loss functions in training & test`

# %% [markdown]
# ### Write your findings here

# %%
# Todo, after you have analysed the model fit history for presence of underfit or overfit, choose an appropriate data augumentation strategy. 
# Your code goes here
data_augument = keras.Sequential([
                             layers.experimental.preprocessing.RandomFlip(mode="horizontal_and_vertical",input_shape=(img_height,img_width,3)),
                             layers.experimental.preprocessing.RandomRotation(0.2, fill_mode='reflect'),
                             layers.experimental.preprocessing.RandomZoom(height_factor=(0.2, 0.3), width_factor=(0.2, 0.3), fill_mode='reflect')
])

# %%
# Todo, visualize how your augmentation strategy works for one instance of training image.
# Your code goes here
plt.figure(figsize=(12, 12))
for images, labels in train_ds.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(data_augument(images)[i].numpy().astype("uint8"))
        plt.title(class_names[labels[i]])
        plt.axis("off")

# %% [markdown]
# ### Todo:
# ### Create the model, compile and train the model

# %%
## You can use Dropout layer if there is an evidence of overfitting in your findings

## Your code goes here
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D
num_classes = 9
model = Sequential([ data_augument,
                    layers.experimental.preprocessing.Rescaling(1./255, input_shape=(img_height, img_width,3))
      
])
model.add(Conv2D(filters = 32, kernel_size = (5,5),padding = 'Same', 
                 activation ='relu', input_shape = (180, 180, 32)))
model.add(Conv2D(filters = 32, kernel_size = (5,5),padding = 'Same', 
                 activation ='relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Conv2D(filters = 64, kernel_size = (5,5),padding = 'Same', 
                 activation ='relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Conv2D(filters = 64, kernel_size = (5,5),padding = 'Same', 
                 activation ='relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Dropout(0.25))


model.add(Flatten())
model.add(Dense(num_classes, activation = "softmax"))

# %% [markdown]
# ### Compiling the model

# %%
## Your code goes here
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %% [markdown]
# ### Training the model

# %%
## Your code goes here, note: train your model for 20 epochs
epochs=30
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/30
# 56/56 [==============================] - 7s 93ms/step - loss: 2.0763 - accuracy: 0.1786 - val_loss: 2.0418 - val_accuracy: 0.1924
# Epoch 2/30
# 56/56 [==============================] - 5s 88ms/step - loss: 2.0295 - accuracy: 0.2026 - val_loss: 2.0203 - val_accuracy: 0.1924
# Epoch 3/30
# 56/56 [==============================] - 5s 88ms/step - loss: 2.0232 - accuracy: 0.2087 - val_loss: 2.0187 - val_accuracy: 0.2058
# Epoch 4/30
# 56/56 [==============================] - 5s 88ms/step - loss: 2.0276 - accuracy: 0.2031 - val_loss: 2.0194 - val_accuracy: 0.1924
# Epoch 5/30
# 56/56 [==============================] - 5s 88ms/step - loss: 2.0289 - accuracy: 0.2121 - val_loss: 2.0293 - val_accuracy: 0.2058
# Epoch 6/30
# 56/56 [==============================] - 5s 87ms/step - loss: 2.0195 - accuracy: 0.1925 - val_loss: 2.0282 - val_accuracy: 0.1499
# Epoch 7/30
# 56/56 [==============================] - 5s 87ms/step - loss: 2.0164 - accuracy: 0.2098 - val_loss: 2.0028 - val_accuracy: 0.2416
# Epoch 8/30
# 56/56 [==============================] - 5s 86ms/step - loss: 2.0524 - accuracy: 0.1875 - val_loss: 2.0234 - val_accuracy: 0.2058
# Epoch 9/30
# 56/56 [==============================] - 5s 86ms/step - loss: 2.0813 - accuracy: 0.2026 - val_loss: 2.0464 - val_accuracy: 0.1924
# Epoch 10/30
# 56/56 [==============================] - 5s 86ms/step - loss: 2.0232 - accuracy: 0.1964 - val_loss: 2.0306 - val_accuracy: 0.2081
# Epoch 11/30
# 56/56 [==============================] - 5s 85ms/step - loss: 2.0189 - accuracy: 0.1948 - val_loss: 2.0287 - val_accuracy: 0.1924
# Epoch 12/30
# 56/56 [==============================] - 5s 86ms/step - loss: 2.0164 - accuracy: 0.1780 - val_loss: 2.0304 - val_accuracy: 0.2081
# Epoch 13/30
# 56/56 [==============================] - 5s 88ms/step - loss: 2.0168 - accuracy: 0.2026 - val_loss: 2.0338 - val_accuracy: 0.1924
# Epoch 14/30
# 56/56 [==============================] - 5s 86ms/step - loss: 2.0168 - accuracy: 0.2081 - val_loss: 2.0353 - val_accuracy: 0.2081
# Epoch 15/30
# 56/56 [==============================] - 5s 86ms/step - loss: 2.0164 - accuracy: 0.2048 - val_loss: 2.0353 - val_accuracy: 0.2081
# Epoch 16/30
# 56/56 [==============================] - 5s 85ms/step - loss: 2.0157 - accuracy: 0.2009 - val_loss: 2.0328 - val_accuracy: 0.2081
# Epoch 17/30
# 56/56 [==============================] - 5s 85ms/step - loss: 2.0141 - accuracy: 0.1992 - val_loss: 2.0364 - val_accuracy: 0.2081
# Epoch 18/30
# 56/56 [==============================] - 5s 85ms/step - loss: 2.0143 - accuracy: 0.2003 - val_loss: 2.0313 - val_accuracy: 0.1924
# Epoch 19/30
# 56/56 [==============================] - 5s 85ms/step - loss: 2.0174 - accuracy: 0.2042 - val_loss: 2.0560 - val_accuracy: 0.1902
# Epoch 20/30
# 56/56 [==============================] - 5s 86ms/step - loss: 2.0179 - accuracy: 0.2087 - val_loss: 2.0235 - val_accuracy: 0.2036
# Epoch 21/30
# 56/56 [==============================] - 5s 85ms/step - loss: 2.2258 - accuracy: 0.2087 - val_loss: 2.0463 - val_accuracy: 0.2058
# Epoch 22/30
# 56/56 [==============================] - 5s 86ms/step - loss: 2.0231 - accuracy: 0.2065 - val_loss: 2.0313 - val_accuracy: 0.2036
# Epoch 23/30
# 56/56 [==============================] - 5s 85ms/step - loss: 2.0187 - accuracy: 0.1970 - val_loss: 2.0272 - val_accuracy: 0.2058
# Epoch 24/30
# 56/56 [==============================] - 5s 85ms/step - loss: 2.0149 - accuracy: 0.1858 - val_loss: 2.0635 - val_accuracy: 0.2081
# Epoch 25/30
# 56/56 [==============================] - 5s 85ms/step - loss: 2.0157 - accuracy: 0.2026 - val_loss: 2.0259 - val_accuracy: 0.1924
# Epoch 26/30
# 56/56 [==============================] - 5s 85ms/step - loss: 2.0160 - accuracy: 0.1869 - val_loss: 2.0219 - val_accuracy: 0.2081
# Epoch 27/30
# 56/56 [==============================] - 5s 85ms/step - loss: 2.0143 - accuracy: 0.2087 - val_loss: 2.0454 - val_accuracy: 0.1924
# Epoch 28/30
# 56/56 [==============================] - 5s 85ms/step - loss: 2.0161 - accuracy: 0.2037 - val_loss: 2.0252 - val_accuracy: 0.1924
# Epoch 29/30
# 56/56 [==============================] - 5s 85ms/step - loss: 2.0168 - accuracy: 0.2009 - val_loss: 2.0244 - val_accuracy: 0.2081
# Epoch 30/30
# 56/56 [==============================] - 5s 85ms/step - loss: 2.0150 - accuracy: 0.2020 - val_loss: 2.0221 - val_accuracy: 0.2058

# %% [markdown]
# ### Visualizing the results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# #### Todo: Write your findings after the model fit, see if there is an evidence of model overfit or underfit. Do you think there is some improvement now as compared to the previous model run?
#
# ### Model 2
# #### `There is no improvement in accuracy`

# %% [markdown]
# #### **Todo:** Find the distribution of classes in the training dataset.
# #### **Context:** Many times real life datasets can have class imbalance, one class can have proportionately higher number of samples compared to the others. Class imbalance can have a detrimental effect on the final model quality. Hence as a sanity check it becomes important to check what is the distribution of classes in the data.

# %%
## Your code goes here.
path_list=[]
lesion_list=[]
for i in class_names:
      
    for j in data_dir_train.glob(i+'/*.jpg'):
        path_list.append(str(j))
        lesion_list.append(i)
dataframe_dict_original = dict(zip(path_list, lesion_list))
original_df = pd.DataFrame(list(dataframe_dict_original.items()),columns = ['Path','Label'])
original_df
# Out:
#                                                    Path              Label
# 0     /content/drive/MyDrive/CNN/CNN_assignment.zip ...  actinic keratosis
# 1     /content/drive/MyDrive/CNN/CNN_assignment.zip ...  actinic keratosis
# 2     /content/drive/MyDrive/CNN/CNN_assignment.zip ...  actinic keratosis
# 3     /content/drive/MyDrive/CNN/CNN_assignment.zip ...  actinic keratosis
# 4     /content/drive/MyDrive/CNN/CNN_assignment.zip ...  actinic keratosis
# ...                                                 ...                ...
# 2234  /content/drive/MyDrive/CNN/CNN_assignment.zip ...    vascular lesion
# 2235  /content/drive/MyDrive/CNN/CNN_assignment.zip ...    vascular lesion
# 2236  /content/drive/MyDrive/CNN/CNN_assignment.zip ...    vascular lesion
# 2237  /content/drive/MyDrive/CNN/CNN_assignment.zip ...    vascular lesion
# 2238  /content/drive/MyDrive/CNN/CNN_assignment.zip ...    vascular lesion
#
# [2239 rows x 2 columns]

# %%
count=[]
for i in class_names:
    count.append(len(list(data_dir_train.glob(i+'/*.jpg'))))
plt.figure(figsize=(25,10))
plt.bar(class_names,count)
# Out:
# <BarContainer object of 9 artists>

# %% [markdown]
# #### **Todo:** Write your findings here:
# #### - Which class has the least number of samples?
# #### - Which classes dominate the data in terms proportionate number of samples?
#
# Ans-1 :- `Seborrheic keratosis has least number of samples`
#
# Ans-2:- `actinic keratosis and dermatofibroma have proportionate number of classes. melanoma and pigmented benign keratosis have proprtionate number of classes`

# %% [markdown]
# #### **Todo:** Rectify the class imbalance
# #### **Context:** You can use a python package known as `Augmentor` (https://augmentor.readthedocs.io/en/master/) to add more samples across all classes so that none of the classes have very few samples.

# %%
# !pip install Augmentor
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting Augmentor
#   Downloading Augmentor-0.2.10-py2.py3-none-any.whl (38 kB)
# Requirement already satisfied: Pillow>=5.2.0 in /usr/local/lib/python3.7/dist-packages (from Augmentor) (7.1.2)
# Requirement already satisfied: numpy>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from Augmentor) (1.21.6)
# Requirement already satisfied: future>=0.16.0 in /usr/local/lib/python3.7/dist-packages (from Augmentor) (0.16.0)
# Requirement already satisfied: tqdm>=4.9.0 in /usr/local/lib/python3.7/dist-packages (from Augmentor) (4.64.0)
# Installing collected packages: Augmentor
# Successfully installed Augmentor-0.2.10

# %% [markdown]
# To use `Augmentor`, the following general procedure is followed:
#
# 1. Instantiate a `Pipeline` object pointing to a directory containing your initial image data set.<br>
# 2. Define a number of operations to perform on this data set using your `Pipeline` object.<br>
# 3. Execute these operations by calling the `Pipeline’s` `sample()` method.

# %%
path_to_training_dataset=pathlib.Path("/content/drive/MyDrive/CNN/CNN_assignment.zip (Unzipped Files)/Skin cancer ISIC The International Skin Imaging Collaboration/Train")
import Augmentor
for i in class_names:
    p = Augmentor.Pipeline(path_to_training_dataset, save_format='jpg')
    p.rotate(probability=0.7, max_left_rotation=10, max_right_rotation=10)
    p.sample(500) ## We are adding 500 samples per class to make sure that none of the classes are sparse.
# Out:
# Initialised with 2239 image(s) found.
# Output directory set to /content/drive/MyDrive/CNN/CNN_assignment.zip (Unzipped Files)/Skin cancer ISIC The International Skin Imaging Collaboration/Train/output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x450 at 0x7FFA4F063590>: 100%|██████████| 500/500 [00:45<00:00, 10.97 Samples/s]
# Initialised with 2239 image(s) found.
# Output directory set to /content/drive/MyDrive/CNN/CNN_assignment.zip (Unzipped Files)/Skin cancer ISIC The International Skin Imaging Collaboration/Train/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7FFA55641910>: 100%|██████████| 500/500 [00:44<00:00, 11.18 Samples/s]
# Initialised with 2239 image(s) found.
# Output directory set to /content/drive/MyDrive/CNN/CNN_assignment.zip (Unzipped Files)/Skin cancer ISIC The International Skin Imaging Collaboration/Train/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7FFA55565E10>: 100%|██████████| 500/500 [00:47<00:00, 10.54 Samples/s]
# Initialised with 2239 image(s) found.
# Output directory set to /content/drive/MyDrive/CNN/CNN_assignment.zip (Unzipped Files)/Skin cancer ISIC The International Skin Imaging Collaboration/Train/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7FFA4F110950>: 100%|██████████| 500/500 [00:42<00:00, 11.72 Samples/s]
# Initialised with 2239 image(s) found.
# Output directory set to /content/drive/MyDrive/CNN/CNN_assignment.zip (Unzipped Files)/Skin cancer ISIC The International Skin Imaging Collaboration/Train/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7FFA555AD450>: 100%|██████████| 500/500 [00:36<00:00, 13.55 Samples/s]
# Initialised with 2239 image(s) found.
# Output directory set to /content/drive/MyDrive/CNN/CNN_assignment.zip (Unzipped Files)/Skin cancer ISIC The International Skin Imaging Collaboration/Train/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7FFAE838BB10>: 100%|██████████| 500/500 [00:46<00:00, 10.69 Samples/s]
# Initialised with 2239 image(s) found.
# Output directory set to /content/drive/MyDrive/CNN/CNN_assignment.zip (Unzipped Files)/Skin cancer ISIC The International Skin Imaging Collaboration/Train/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7FFAE8377890>: 100%|██████████| 500/500 [00:38<00:00, 12.98 Samples/s]
# Initialised with 2239 image(s) found.
# Output directory set to /content/drive/MyDrive/CNN/CNN_assignment.zip (Unzipped Files)/Skin cancer ISIC The International Skin Imaging Collaboration/Train/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7FFA4F31BD50>: 100%|██████████| 500/500 [00:55<00:00,  8.96 Samples/s]
# Initialised with 2239 image(s) found.
# Output directory set to /content/drive/MyDrive/CNN/CNN_assignment.zip (Unzipped Files)/Skin cancer ISIC The International Skin Imaging Collaboration/Train/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7FFA567F8AD0>: 100%|██████████| 500/500 [00:46<00:00, 10.79 Samples/s]

# %% [markdown]
# Augmentor has stored the augmented images in the output sub-directory of each of the sub-directories of skin cancer types.. Lets take a look at total count of augmented images.

# %%
data_dir_train1 = pathlib.Path("/content/drive/MyDrive/CNN/CNN_assignment.zip (Unzipped Files)/Skin cancer ISIC The International Skin Imaging Collaboration/Train/output")
image_count_train1 = len(list(data_dir_train1.glob('*/*.jpg')))
print(image_count_train1)
# Out:
# 4500

# %% [markdown]
# ### Lets see the distribution of augmented data after adding new images to the original training data.

# %%
from glob import glob
path_list = [x for x in glob(os.path.join(data_dir_train1, '*','output', '*.jpg'))]
path_list
# Out:
# []

# %%
lesion_list_new = [os.path.basename(os.path.dirname(os.path.dirname(y))) for y in glob(os.path.join(data_dir_train, '*','output', '*.jpg'))]
lesion_list_new
# Out:
# []

# %%
# dataframe_dict_new = dict(zip(path_list_new, lesion_list_new))

# %%
# df2 = pd.DataFrame(list(dataframe_dict_new.items()),columns = ['Path','Label'])
# new_df = original_df.append(df2)

# %%
# new_df['Label'].value_counts()

# %% [markdown]
# So, now we have added 500 images to all the classes to maintain some class balance. We can add more images as we want to improve training process.

# %% [markdown]
# #### **Todo**: Train the model on the data created using Augmentor

# %%
batch_size = 32
img_height = 180
img_width = 180

# %% [markdown]
# #### **Todo:** Create a training dataset

# %%
data_dir_train1="/content/drive/MyDrive/CNN/CNN_assignment.zip (Unzipped Files)/Skin cancer ISIC The International Skin Imaging Collaboration/Train/output"
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train1,
  seed=123,
  validation_split = 0.2,
  subset = "training",
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 4500 files belonging to 9 classes.
# Using 3600 files for training.

# %% [markdown]
# #### **Todo:** Create a validation dataset

# %%
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train1,
  seed=123,
  validation_split = 0.2,
  subset = 'validation',
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 4500 files belonging to 9 classes.
# Using 900 files for validation.

# %% [markdown]
# #### **Todo:** Create your model (make sure to include normalization)

# %%
## your code goes here
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D
num_classes = 9
model = Sequential([ 
                    layers.experimental.preprocessing.Rescaling(1./255, input_shape=(img_height, img_width,3))
      
])
model.add(Conv2D(filters = 32, kernel_size = (5,5),padding = 'Same', 
                 activation ='relu', input_shape = (180, 180, 32)))
model.add(Conv2D(filters = 32, kernel_size = (5,5),padding = 'Same', 
                 activation ='relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Conv2D(filters = 64, kernel_size = (5,5),padding = 'Same', 
                 activation ='relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Conv2D(filters = 64, kernel_size = (5,5),padding = 'Same', 
                 activation ='relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Dropout(0.25))


model.add(Flatten())
model.add(Dense(num_classes, activation = "softmax"))

# %% [markdown]
# #### **Todo:** Compile your model (Choose optimizer and loss function appropriately)

# %%
## your code goes here
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %% [markdown]
# #### **Todo:**  Train your model

# %%
epochs = 50
## Your code goes here, use 50 epochs.
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/50
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1082: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
#   return dispatch_target(*args, **kwargs)
# 113/113 [==============================] - 21s 170ms/step - loss: 1.9547 - accuracy: 0.2567 - val_loss: 1.8285 - val_accuracy: 0.2956
# Epoch 2/50
# 113/113 [==============================] - 22s 185ms/step - loss: 1.6570 - accuracy: 0.3922 - val_loss: 1.5372 - val_accuracy: 0.4422
# Epoch 3/50
# 113/113 [==============================] - 20s 171ms/step - loss: 1.5739 - accuracy: 0.4478 - val_loss: 1.6848 - val_accuracy: 0.4233
# Epoch 4/50
# 113/113 [==============================] - 20s 169ms/step - loss: 1.5047 - accuracy: 0.4725 - val_loss: 1.4457 - val_accuracy: 0.4833
# Epoch 5/50
# 113/113 [==============================] - 21s 177ms/step - loss: 1.3647 - accuracy: 0.5217 - val_loss: 1.4041 - val_accuracy: 0.5100
# Epoch 6/50
# 113/113 [==============================] - 20s 168ms/step - loss: 1.2758 - accuracy: 0.5544 - val_loss: 1.3289 - val_accuracy: 0.5422
# Epoch 7/50
# 113/113 [==============================] - 20s 167ms/step - loss: 1.1584 - accuracy: 0.5911 - val_loss: 1.2514 - val_accuracy: 0.5500
# Epoch 8/50
# 113/113 [==============================] - 20s 167ms/step - loss: 1.0840 - accuracy: 0.6189 - val_loss: 1.5088 - val_accuracy: 0.5156
# Epoch 9/50
# 113/113 [==============================] - 20s 168ms/step - loss: 0.9826 - accuracy: 0.6700 - val_loss: 1.1677 - val_accuracy: 0.6200
# Epoch 10/50
# 113/113 [==============================] - 20s 169ms/step - loss: 0.9128 - accuracy: 0.6733 - val_loss: 1.3129 - val_accuracy: 0.5800
# Epoch 11/50
# 113/113 [==============================] - 21s 178ms/step - loss: 0.7249 - accuracy: 0.7400 - val_loss: 1.2310 - val_accuracy: 0.6367
# Epoch 12/50
# 113/113 [==============================] - 20s 167ms/step - loss: 0.6291 - accuracy: 0.7789 - val_loss: 1.2207 - val_accuracy: 0.6633
# Epoch 13/50
# 113/113 [==============================] - 20s 168ms/step - loss: 0.5641 - accuracy: 0.7975 - val_loss: 1.2708 - val_accuracy: 0.6611
# Epoch 14/50
# 113/113 [==============================] - 20s 168ms/step - loss: 0.5580 - accuracy: 0.7953 - val_loss: 1.2555 - val_accuracy: 0.6778
# Epoch 15/50
# 113/113 [==============================] - 20s 167ms/step - loss: 0.4111 - accuracy: 0.8589 - val_loss: 1.3819 - val_accuracy: 0.6944
# Epoch 16/50
# 113/113 [==============================] - 21s 177ms/step - loss: 0.4124 - accuracy: 0.8603 - val_loss: 1.5263 - val_accuracy: 0.6722
# Epoch 17/50
# 113/113 [==============================] - 20s 167ms/step - loss: 0.3063 - accuracy: 0.8961 - val_loss: 1.6071 - val_accuracy: 0.6733
# Epoch 18/50
# 113/113 [==============================] - 20s 166ms/step - loss: 0.2981 - accuracy: 0.9011 - val_loss: 1.6145 - val_accuracy: 0.6844
# Epoch 19/50
# 113/113 [==============================] - 20s 167ms/step - loss: 0.2232 - accuracy: 0.9275 - val_loss: 1.6418 - val_accuracy: 0.6789
# Epoch 20/50
# 113/113 [==============================] - 20s 167ms/step - loss: 0.2388 - accuracy: 0.9258 - val_loss: 1.6687 - val_accuracy: 0.6989
# Epoch 21/50
# 113/113 [==============================] - 20s 169ms/step - loss: 0.3353 - accuracy: 0.8889 - val_loss: 1.7433 - val_accuracy: 0.6767
# Epoch 22/50
# 113/113 [==============================] - 20s 167ms/step - loss: 0.2608 - accuracy: 0.9156 - val_loss: 1.9247 - val_accuracy: 0.6700
# Epoch 23/50
# 113/113 [==============================] - 21s 178ms/step - loss: 0.1672 - accuracy: 0.9472 - val_loss: 1.7298 - val_accuracy: 0.7189
# Epoch 24/50
# 113/113 [==============================] - 20s 169ms/step - loss: 0.1937 - accuracy: 0.9389 - val_loss: 1.9679 - val_accuracy: 0.6989
# Epoch 25/50
# 113/113 [==============================] - 20s 167ms/step - loss: 0.1922 - accuracy: 0.9397 - val_loss: 1.7931 - val_accuracy: 0.7044
# Epoch 26/50
# 113/113 [==============================] - 20s 167ms/step - loss: 0.1547 - accuracy: 0.9503 - val_loss: 1.7869 - val_accuracy: 0.7089
# Epoch 27/50
# 113/113 [==============================] - 20s 168ms/step - loss: 0.1807 - accuracy: 0.9411 - val_loss: 1.6760 - val_accuracy: 0.7011
# Epoch 28/50
# 113/113 [==============================] - 20s 167ms/step - loss: 0.1238 - accuracy: 0.9600 - val_loss: 1.9667 - val_accuracy: 0.7122
# Epoch 29/50
# 113/113 [==============================] - 21s 179ms/step - loss: 0.1408 - accuracy: 0.9531 - val_loss: 2.0027 - val_accuracy: 0.6911
# Epoch 30/50
# 113/113 [==============================] - 20s 167ms/step - loss: 0.1366 - accuracy: 0.9589 - val_loss: 2.1046 - val_accuracy: 0.7000
# Epoch 31/50
# 113/113 [==============================] - 20s 170ms/step - loss: 0.1538 - accuracy: 0.9536 - val_loss: 2.0406 - val_accuracy: 0.7211
# Epoch 32/50
# 113/113 [==============================] - 20s 168ms/step - loss: 0.1088 - accuracy: 0.9697 - val_loss: 2.0448 - val_accuracy: 0.7178
# Epoch 33/50
# 113/113 [==============================] - 20s 167ms/step - loss: 0.1424 - accuracy: 0.9561 - val_loss: 1.9316 - val_accuracy: 0.6956
# Epoch 34/50
# 113/113 [==============================] - 21s 178ms/step - loss: 0.1735 - accuracy: 0.9469 - val_loss: 1.7440 - val_accuracy: 0.7178
# Epoch 35/50
# 113/113 [==============================] - 20s 167ms/step - loss: 0.1492 - accuracy: 0.9544 - val_loss: 1.9099 - val_accuracy: 0.7089
# Epoch 36/50
# 113/113 [==============================] - 20s 168ms/step - loss: 0.1190 - accuracy: 0.9650 - val_loss: 1.9033 - val_accuracy: 0.7078
# Epoch 37/50
# 113/113 [==============================] - 20s 170ms/step - loss: 0.1001 - accuracy: 0.9728 - val_loss: 2.2823 - val_accuracy: 0.7122
# Epoch 38/50
# 113/113 [==============================] - 20s 167ms/step - loss: 0.0894 - accuracy: 0.9722 - val_loss: 2.9743 - val_accuracy: 0.6500
# Epoch 39/50
# 113/113 [==============================] - 20s 167ms/step - loss: 0.1506 - accuracy: 0.9544 - val_loss: 2.1395 - val_accuracy: 0.7167
# Epoch 40/50
# 113/113 [==============================] - 21s 178ms/step - loss: 0.1073 - accuracy: 0.9678 - val_loss: 2.1597 - val_accuracy: 0.7067
# Epoch 41/50
# 113/113 [==============================] - 20s 168ms/step - loss: 0.1178 - accuracy: 0.9636 - val_loss: 2.3889 - val_accuracy: 0.7078
# Epoch 42/50
# 113/113 [==============================] - 20s 169ms/step - loss: 0.1592 - accuracy: 0.9528 - val_loss: 2.0025 - val_accuracy: 0.7222
# Epoch 43/50
# 113/113 [==============================] - 20s 167ms/step - loss: 0.1099 - accuracy: 0.9675 - val_loss: 2.3751 - val_accuracy: 0.7144
# Epoch 44/50
# 113/113 [==============================] - 20s 168ms/step - loss: 0.1166 - accuracy: 0.9614 - val_loss: 2.0807 - val_accuracy: 0.7089
# Epoch 45/50
# 113/113 [==============================] - 20s 169ms/step - loss: 0.1095 - accuracy: 0.9694 - val_loss: 2.3466 - val_accuracy: 0.7078
# Epoch 46/50
# 113/113 [==============================] - 21s 179ms/step - loss: 0.0872 - accuracy: 0.9764 - val_loss: 2.5272 - val_accuracy: 0.7044
# Epoch 47/50
# 113/113 [==============================] - 20s 168ms/step - loss: 0.0808 - accuracy: 0.9764 - val_loss: 2.8312 - val_accuracy: 0.7133
# Epoch 48/50
# 113/113 [==============================] - 20s 169ms/step - loss: 0.1230 - accuracy: 0.9675 - val_loss: 2.3432 - val_accuracy: 0.7022
# Epoch 49/50
# 113/113 [==============================] - 20s 168ms/step - loss: 0.1343 - accuracy: 0.9619 - val_loss: 2.0630 - val_accuracy: 0.7000
# Epoch 50/50
# 113/113 [==============================] - 20s 168ms/step - loss: 0.1228 - accuracy: 0.9653 - val_loss: 3.1815 - val_accuracy: 0.6878

# %% [markdown]
# #### **Todo:**  Visualize the model results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# #### **Todo:**  Analyze your results here. Did you get rid of underfitting/overfitting? Did class rebalance help?
#
# - `Accuracy on training data has increased by using Augmentor library`
# - `Model is still overfitting and can be solved by add more layer,neurons or adding dropout layers.`
# - `Also it can be further improved by tuning the hyperparameter`
